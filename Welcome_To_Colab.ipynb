# %% [markdown]
# <a href="https://colab.research.google.com/github/thrinadh-88/second-github-programs/blob/master/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import ai
prompt = input()
response = ai.generate_text(prompt)
print(response)
while True:
  prompt = input()
  response = ai.generate_text(prompt)
  print(response)
  if prompt == "TQ":
    break
